# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.shape
# Out:
# (1338, 7)

# %%
print(data['sex'].value_counts())
print(data['smoker'].value_counts())
print(data['children'].value_counts())
print(data['region'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# no     1064
# yes     274
# Name: smoker, dtype: int64
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# #### Converting Catagorical data to numerical data / Encoding

# %%
data['sex'] = data['sex'].map({'male':1,'female':0})
data['smoker'] = data['smoker'].map({'yes':1,'no':0})
data['region'] = data['region'].map({'southeast':0,'southwest':1,'northwest':2,'northeast':3})
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       1  16884.92400
# 1   18    1  33.770         1       0       0   1725.55230
# 2   28    1  33.000         3       0       0   4449.46200
# 3   33    1  22.705         0       0       2  21984.47061
# 4   32    1  28.880         0       0       2   3866.85520

# %% [markdown]
# ## Exporatory Data Analysis
#
# #### Uni varient Analysis-When Single variable is analysed at once time

# %%
plt.figure(figsize=(13,7))
sns.histplot(data.age,bins=20,kde=True,color='blue')

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel("Frequency of each age")
# Out:
# Text(0, 0.5, 'Frequency of each age')

# %% [markdown]
# #### Max people in the above data set are of the age 19 to 20 with a count of 165 or 170

# %%
plt.figure(figsize=(13,7))
sns.countplot(x='sex',data = data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #### Both the count of male and female almost equal

# %%
plt.figure(figsize=(13,7))
sns.histplot(data.bmi,bins=78,kde=True,color='green')

plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel("Frequency of each bmi")
# Out:
# Text(0, 0.5, 'Frequency of each bmi')

# %% [markdown]
# #### Majority of people have BMI between 25 and 40, which is considered an overweight and could be a major factor in increased medical charges

# %%
plt.figure(figsize=(13,7))
sns.histplot(data.charges,bins=100,kde=False,color='magenta')

plt.title('Charges Distribution')
plt.xlabel('Charges')
plt.ylabel("Distribution of Charges")
# Out:
# Text(0, 0.5, 'Distribution of Charges')

# %% [markdown]
# #### Its is a left skwed graph with mean lying somehwere to the left side of the graph approximalty equal to 13270.42 Also there lies more number of  people having their charges between the range of 2000 to 12000

# %%
data['charges'].describe()
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %% [markdown]
# ### Bi-variate Analysis

# %%
# Relation between Gender and Smoker

plt.figure(figsize=(13,7))
sns.catplot(x='smoker',kind='count',hue='sex',data=data)

plt.xlabel("Smoker")
plt.ylabel('Count')
plt.show()

# %%
# Male smokers are more in number than female smoker, so One can assume that medical expence dfro male will be more as compared to frmale

# %%
plt.figure(figsize=(13,7))
sns.boxplot(y = 'smoker',x ='charges',data = data[(data.sex==0)],orient='h')
# Out:
# <Axes: xlabel='charges', ylabel='smoker'>

# %%
plt.figure(figsize=(13,7))
sns.boxplot(y = 'smoker',x ='charges',data = data[(data.sex==1)],orient='h')
# Out:
# <Axes: xlabel='charges', ylabel='smoker'>

# %%
# The assumption is true, that the medical expence of males is greater than that of females. In addition to that the medical 
# expence of smokers is > non-smokers.

# %%
cor = data.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.006308  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185 -0.012816  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750 -0.262754  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.001205  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.038873  0.787251
# region    0.006308 -0.012816 -0.262754  0.001205 -0.038873  1.000000 -0.039473
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.039473  1.000000

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(cor, annot = True, cmap = 'BuGn_r')
# Out:
# <Axes: >

# %%
# There is no relation between charges and region but a storng relation between smoker and charges meaning that if someone 
# smokes his/her medical charges will be high.
# Also there is a marginal relation between charges and bmi and a very week relation between charges and children,gender
# Age is also to some extent is creating a relation with the charges

# %% [markdown]
# #### By observing the plot we can state that smokers has more expences so it has a high impact on insurance charges followed by age and bmi where as region, gender and children has np imptact

# %%
plt.figure(figsize=(13, 7))
sns.catplot(x='smoker',y='age',kind='swarm',data = data)

# %% [markdown]
# *From above graph, we can observe that there is a significant number of smokers at the age 19.*

# %% [markdown]
# ### Multi-Variant Analysis - When we analyse using more than two variables.

# %%
plt.figure(figsize=(13,7))

plt.title("Scatter Plot For Charges of non-Smoker")
sns.scatterplot(x='age',y = 'charges',data=data[(data.smoker==0)])

plt.show()

# %% [markdown]
# *Majority of the points shows that he medical expenses increase wiht the agewhich may due to the fact that older people are more prone to illness. But there are some outliers which shows other illness or expences which may lead to increase in medical expenses.*

# %%
plt.figure(figsize=(13,7))

plt.title("Scatter Plot For Charges of non-Smoker")
sns.scatterplot(x='age',y = 'charges',data=data[(data.smoker==1)])

plt.show()

# %% [markdown]
# *In this graph there are two segments, one with high medical expense which may be due to high smoking related illness and other with low medical expense which may be due to age related illness*
#
# Now, in order to get more clear idea we combine both the graphs.

# %%
# Age charges distribution.

plt.figure(figsize = (8,10))
sns.lmplot(x='age',y='charges',data = data,hue = 'smoker')
plt.show()

# %% [markdown]
# *Now we can clearly undersatnd the difference in the charges wrt age and smoking habits. The medical expense of smoker is higher than that of non smokersirrespective of age. In non-smokers, the cost of treatment increases wiht age which is kind of obvious.*

# %%
# relation b/w medical BMI and Medical Charges

plt.figure(figsize = (13,7))
sns.displot(data[(data.bmi > 30)]['charges'],kde = True)
plt.show()

# %%
plt.figure(figsize = (13,7))
sns.displot(data[(data.bmi < 30)]['charges'],kde = True)
plt.show()

# %% [markdown]
# *Therefore, people with BMI less than 30 are spending less where a people with BMI > 30 are spending more*

# %%
data.drop(['region'],axis = 1,inplace = True)
data.head()
# Out:
#    age  sex     bmi  children  smoker      charges
# 0   19    0  27.900         0       1  16884.92400
# 1   18    1  33.770         1       0   1725.55230
# 2   28    1  33.000         3       0   4449.46200
# 3   33    1  22.705         0       0  21984.47061
# 4   32    1  28.880         0       0   3866.85520

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Liner Regression

# %%
x = data.drop('charges',axis=1)
y = data.charges
x,y
# Out:
# (      age  sex     bmi  children  smoker
#  0      19    0  27.900         0       1
#  1      18    1  33.770         1       0
#  2      28    1  33.000         3       0
#  3      33    1  22.705         0       0
#  4      32    1  28.880         0       0
#  ...   ...  ...     ...       ...     ...
#  1333   50    1  30.970         3       0
#  1334   18    0  31.920         0       0
#  1335   18    0  36.850         0       0
#  1336   21    0  25.800         0       0
#  1337   61    0  29.070         0       1
#
#  [1338 rows x 5 columns],
#  0       16884.92400
#  1        1725.55230
#  2        4449.46200
#  3       21984.47061
#  4        3866.85520
#             ...
#  1333    10600.54830
#  1334     2205.98080
#  1335     1629.83350
#  1336     2007.94500
#  1337    29141.36030
#  Name: charges, Length: 1338, dtype: float64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1003, 5), (335, 5), (1003,), (335,))

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression() 

reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([11457.24748797,  9925.93074028, 37768.54941888, 15853.34679049,
#         6939.11972533,  3715.15809068,  1226.51797859, 14013.62531872,
#         8801.37793745,  7319.3569299 ,  4273.75316151, 10130.71955326,
#         9085.31708787,  4373.32320457, 27814.85680664, 11178.7533822 ,
#        11185.96123339,  5630.52468867,  8076.08092103, 26738.70765833,
#        33571.19206907, 14028.13563512, 11218.6467869 , 32627.93297826,
#         4586.6864    ,  8662.71797281,   909.82505247, 10181.12419998,
#         4318.89099156, 10226.29974927,  8827.54515889, 40279.78845676,
#        15797.33819958, 14003.57232067, 24541.57502951,  4754.90669146,
#        12888.4411817 , 30986.42695074, 33296.10937045,  3923.72690408,
#         3729.50340695,  4518.10338943, 30179.67003291, 39152.46681933,
#        28159.50615257,  4858.31074493, 11075.11507975,  7719.48440006,
#         3314.0509843 , 10750.82941843,  5170.52098751,  3301.78200967,
#        33383.67630651, 37846.88608306, 16194.84338063,  6620.18331508,
#         6111.94095952,  9324.67953075,  9476.64100052, 11624.72746611,
#         2239.12792237, 38688.83889054, 15262.80744228, 12051.9986672 ,
#        13470.23402007, 14114.3756173 , 26350.32777056, 31988.00522308,
#         1469.65231028,  9964.34448119, 12644.44028247, 12006.310953  ,
#        25675.62991957, 15864.55155214, 11084.63352155, 12188.53847038,
#         7026.84853479, 10035.77480254, 29834.56541685, 39263.29154446,
#        11569.33391865, 37390.06876738,  4065.35433313,  9694.88715526,
#        34310.67351274, 29449.7721265 ,  8730.99241162,  4744.22942264,
#        12371.65807336, 30705.73123348,  9468.75799532, 11679.5619021 ,
#         7702.85079546,  9377.52003795,  7892.09573487,  6830.94466552,
#        35550.50932188, 33506.30150831,  7405.80363197, 15197.50446839,
#         4458.44505284,  8565.87607125,  6721.16882546, 31943.09755246,
#        32847.97139428,  1970.81112169,  9481.69506055,  6399.5145277 ,
#        13994.14455622, 37473.56543302, 10084.78538889, 10760.22453756,
#        10023.80932574, 26563.36409246, 40087.17184048,  8098.58009501,
#          825.48832172,  9384.35006852, 15386.59050827,  9425.06829946,
#        35505.40199478,  7280.3912938 , 17011.37538057,  9066.55418352,
#         8583.34974096,  2964.01661524, 32531.23464833, 31463.89212044,
#        39703.35921301,  5305.35201567,  9747.58409083,  4018.38958547,
#         8074.59209374,  8323.3639993 , 32062.42642683, 30299.54470188,
#        30379.08915067,  9289.05091518, 33022.71924513,  3264.12288332,
#         3490.33036656, 10971.36683536, 13436.46186225, 12330.70559344,
#         5377.17034778, 15839.94850742, 15192.61643515,  2378.31537985,
#           58.01273899, 10472.15612186,  6998.9521365 , 32095.43275328,
#        11864.99819629,  2843.8221577 ,  6093.98761732,  8301.75481084,
#         4265.43841477,  2636.5455528 , 11166.19116372, 12230.84528039,
#         6789.65818483, 16591.89851836, 11651.50363041, 14189.00861486,
#         2931.28724189,  6801.31508987, 23653.33166555,  7128.52341141,
#         5129.07263341,  5467.83699249,  6529.90356543,  4842.37684958,
#         9770.61685824,  5746.59383915,  6072.04145423,  7062.50251554,
#         3440.11921189,  5561.92947692, 37605.35364734,  1178.66934599,
#        12364.69667234,  8770.28096302, 13473.86137442,  5810.96910827,
#         4920.87851389, 36059.78836133,  3946.01325759,  2447.27621103,
#        14896.2118442 , 12116.59895797, 34649.70373945,  5250.34647897,
#         6066.73490728, 31820.59151993,  5924.5565674 ,  2587.19589174,
#         8003.32677253,  9452.00633715,  8332.0544243 ,  5666.10747338,
#        12608.47357656, 38819.80837921, 13448.18191554, 29321.67435096,
#         6585.90605575, 35830.38727632,  3460.5389175 , 12243.29755692,
#         9381.72777941,  6481.49582134, 11109.70091084, 14004.82182504,
#         5060.47429493,  4710.42973572,  8248.14646124,  1833.46278301,
#         7474.28079015,  4129.01880752, 13341.00693609,  4053.24937427,
#        10240.80693893,  6875.16907051,  9591.32420225,  2093.82024468,
#        13428.01476067, 16459.4677315 , 15187.00028978, 10946.97661112,
#         5958.43569332,  2820.11832584,  2439.60202579, 12843.81455374,
#        14339.29699263,  4562.85216051,  4353.04707059,  9754.70126466,
#         9546.44502354, 27865.11178114,  7249.45619277, 10110.29984764,
#         6665.39448353, 29606.44033864, 11281.75112314,  7132.80352845,
#        10042.19338282, 12010.50649327,  2692.15802134, 10555.09664988,
#         1249.01715258,  6721.83691607, 28959.41176421, 38906.14000157,
#         6594.5038562 ,  8394.43167507,  2121.5760452 ,   194.10547271,
#        10794.08127215,  4535.09227044,  4875.10622293,  2956.03385824,
#         7478.97332032, 33749.76374018, 37730.56341901, 14494.49579496,
#         8124.09455376, 15442.98912097, 33187.91600887,  9126.71561058,
#        33846.28994273,  3786.89995764, 30239.33744395,  8430.97579423,
#        13645.37189271,  4015.58712119, 32623.6864909 ,  7871.51102912,
#        11631.41079832,  9600.16541517,  4090.09484889, 12988.46848437,
#        11565.6658712 ,  8250.11896152, 12856.73629106,  2419.92873407,
#        10083.80673704,  5818.71151569, 11221.44411342, 31255.65418108,
#        10039.86337472,   969.82246378,   577.5219778 , 39278.16435355,
#         9332.66838833,  6937.20213035, 13686.86406664, 12890.07460727,
#        27706.73269392,  7544.8811475 ,  7271.44617569, 12399.28250343,
#         2832.69274549,  4131.58092223, 24878.40460754, 26625.32691908,
#        13436.38143887,  2970.86494758,  5285.28260157,  9724.4698734 ,
#        11976.35041425, 23389.00368526, 30709.40947108, 10271.69109289,
#        24131.21735998,  2791.03557144, 11605.78937148,  7746.05994506,
#         7901.18442461,   691.63082918,  7442.97812249, 35364.93242991,
#         5706.78188448,  5840.63327643,   284.87298492, 10982.58989877,
#         6889.96244061, 10183.82183853, 39221.62826981, 27717.24096209,
#        11063.11398379, 35723.01167757, 14429.07774137,  6705.2471313 ,
#        11152.09229762,  7200.55554836, 36542.08241652])

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score= ",r2_score(y_test, y_pred))
# Out:
# MAE: 3987.1986506275825
# RMSE: 5678.017317091146
# R2 Score=  0.7952171980481992

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 2)
poly_reg
# Out:
# PolynomialFeatures()

# %%
#Transforming the feature to a higher degree
x_train_poly = poly_reg.fit_transform(x_train)

# Splitting the data
x_train,x_test,y_train,y_test = train_test_split(x_train_poly,y_train,test_size=0.2,random_state=0)

# %%
# Train the Model
plr = LinearRegression()
plr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Meking Predictions
y_pred_pr = plr.predict(x_test)
y_pred_pr
# Out:
# array([33903.67690238, 10214.28309743,  7152.80305978,  6213.54478854,
#        10924.28136039,  8997.82286256,  4998.45583226,  4986.12763895,
#        12601.42779167,  3750.6165746 , 11383.17211306,  7550.21215394,
#        12143.87444733,  4849.84865781, 23327.67744641,  3592.08036244,
#        24795.37242715, 10448.12733481,  4005.95192891, 10572.79927813,
#         2707.88535245, 11178.97531592,  9956.63243767, 11949.25664265,
#         9101.53826142, 33591.67437584,  6159.03150864,  9888.20371195,
#        13454.96297563, 12661.12604511,  8147.80598438, 11783.49349467,
#        12529.93405018, 14064.00125117,  7975.47266274,  4044.12615162,
#        21253.85062212,  4477.99656574,  2182.96994953,  2899.76530133,
#         6530.21994467,  9318.34499583, 11925.96020543,  3428.83421165,
#        12927.26263588, 15072.61620179, 11568.80515378, 12677.01284572,
#         2818.14868157, 13685.13131328,  3021.90120592,  3815.535328  ,
#        12983.16357927,  2641.17037299, 41807.13447464,  4175.27816624,
#         7588.50210898, 12143.68430908,  1992.32731388,  9135.3873255 ,
#        41746.21005891, 40525.2214524 , 26121.12393066,  2141.57009231,
#         7084.56855823, 12340.39980679,  2477.16991434,  5230.12329673,
#         2747.35129263, 13597.79462124,  5308.37289179,  2473.4909153 ,
#        13584.04091196, 13554.64988612,  8577.98806344, 10787.12130413,
#        16419.39378563,  3284.45594357, 33586.06620893, 21390.96690897,
#         7806.23506418, 10576.39243529,  6653.95941403,  8421.63096376,
#         2929.35903933,  7903.56729769,  3656.55416945,  4114.98774894,
#        25417.36715487, 12538.26607672,  4416.68553553, 13038.32337692,
#         2808.43150457, 27093.71874014, 40227.91818664,  3198.22536247,
#        40268.02863269, 35774.0497702 ,  2477.16991434, 10736.56279893,
#        11611.80495552, 49988.52973781, 16275.41842143,  6457.19211254,
#        10045.69326648,  6275.42262579, 56186.15021679, 34080.3013315 ,
#         6838.33899362, 14462.73757924,  9573.79793947,  9863.36740123,
#        14122.30564776,  5324.09154254, 11091.69637135,  2259.62090897,
#        27265.54246215,  4420.87179862,  7791.16003008,  4116.87508787,
#         4958.13134173, 20752.32145221,  5176.41755453, 33353.37206603,
#         8671.24965309, 41316.42328035, 11768.95660757, 13212.14216006,
#         8563.72703976,  6006.19619105,  6623.71891887, 12471.71447435,
#         6847.27339926, 10983.34101747, 26742.14990025, 25002.58726603,
#         3439.74367712, 46654.5240586 , 12889.04859084, 30552.59730432,
#        34490.02463491,  5327.71876766, 10822.4270286 , 42974.60595383,
#         6357.83779659, 10177.18740254,  9685.70551751,  3728.41093896,
#         6185.25333462,  8743.40158317,  6682.08651583, 12153.85133689,
#        11509.3083663 , 27560.67180082,  4068.74116254, 13815.81019647,
#         2917.22850506, 19413.43504954,  4294.89588921,  6394.07276264,
#         9328.00919804, 17041.49215589,  7646.13774054,  8101.35063838,
#        10093.99513857, 10172.52308763, 12095.43671078, 46649.82035882,
#         9826.18866355, 16101.45527519, 11132.33182658, 13391.33394278,
#         9455.47565051, 14025.07690168,  6600.55969588, 38362.09657355,
#         5542.66852455, 17460.58249201, 11742.08340072, 10090.96643397,
#        44492.87847412, 11235.59510242, 14909.24994444,  7293.12552008,
#        30920.6424095 , 38008.8502215 ,  7112.22520483, 11275.55020341,
#         1598.01040084,  3959.69811394, 14142.00471675,  7466.12628897,
#        11090.17718873, 27390.07334255,  6435.43631647, 15160.31147306,
#         6479.21113742, 12451.87823951,  5661.44763411, 10484.23030288,
#        13545.24062996])

# %%
# Model Evaluation
from sklearn import metrics
from sklearn.metrics import r2_score
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_pr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_pr)))
print("R2 Score= ",r2_score(y_test, y_pred_pr))
# Out:
# MAE: 3238.6785371272586
# RMSE: 5409.076526902022
# R2 Score=  0.7915151210260605

# %% [markdown]
# # Making A Prediction System

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker      charges
# 0   19    0  27.900         0       1  16884.92400
# 1   18    1  33.770         1       0   1725.55230
# 2   28    1  33.000         3       0   4449.46200
# 3   33    1  22.705         0       0  21984.47061
# 4   32    1  28.880         0       0   3866.85520

# %%
# Input Values
age = 21
sex = 1
bmi = 27
children = 0
smoker = 1

# %%
# Predicting the Charges
charge = reg.predict([[age,sex,bmi,children,smoker]])
print('The charges of this new patient is $',charge)
# Out:
# The charges of this new patient is $ [25833.17904279]

# %% [markdown]
# ## OLS MODEL: -
# ***Ordinary List Square.***
#
#
#
# ***It is used to estimate the value of weights and bias.***

# %%
import statsmodels.api as sm

# %%
# Add constants to predicator [Features] variables.

X = sm.add_constant(x)

# %%
result = sm.OLS(y,X).fit()

# Printing the summary variable.

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     798.0
# Date:                Mon, 11 Sep 2023   Prob (F-statistic):               0.00
# Time:                        10:24:05   Log-Likelihood:                -13551.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1332   BIC:                         2.715e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.205e+04    951.260    -12.670      0.000   -1.39e+04   -1.02e+04
# age          257.7350     11.904     21.651      0.000     234.383     281.087
# sex         -128.6399    333.361     -0.386      0.700    -782.609     525.329
# bmi          322.3642     27.419     11.757      0.000     268.576     376.153
# children     474.4111    137.856      3.441      0.001     203.973     744.849
# smoker      2.382e+04    412.523     57.750      0.000     2.3e+04    2.46e+04
# ==============================================================================
# Omnibus:                      301.103   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              720.380
# Skew:                           1.214   Prob(JB):                    3.73e-157
# Kurtosis:                       5.650   Cond. No.                         295.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Regularization

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

# %%
# Ridge Regression

Ridgemodel = Ridge()
Ridgemodel
# Out:
# Ridge()

# %%
Ridgemodel.fit(x_train, y_train)
# Out:
# Ridge()

# %%
# Testing the Model.

r_pred = Ridgemodel.predict(x_test)
r2_score(y_test,r_pred)
# Out:
# 0.7910371539658424
